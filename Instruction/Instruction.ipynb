# %% [markdown]
# # Rythm and Musical Notation

# %% [markdown]
# <hr />

# %% [markdown]
# ### The Pulse

# %% [markdown]
# compare it with the heart beat and your pace walking
# and then give the theoretical explanation -> (just an animation of a heart beat and a person walking)

# %% [markdown]
# <video width="320" height="240" controls>
#   <source src="heart_beating.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %%
from IPython.display import display, Image

with open('HeartPulseAnimation.gif','rb') as file:
    display(Image(file.read(), format='gif'))

# %%
with open('Walk.gif','rb') as file:
    display(Image(file.read(), format='gif'))

# %%
from IPython.display import HTML, display

html_content = """
<div style="display: flex;">
  <div style="flex: 50%;">
    <img src="HeartPulseAnimation.gif" alt="Heart Pulse Animation" style="width:100%">
  </div>
  <div style="flex: 50%;">
    <img src="Walk.gif" alt="Walk Animation" style="width:100%">
  </div>
</div>
"""

display(HTML(html_content))
# Out:
# <div style="display: flex;">
#   <div style="flex: 50%;">
#     <img src="HeartPulseAnimation.gif" alt="Heart Pulse Animation" style="width:100%">
#   </div>
#   <div style="flex: 50%;">
#     <img src="Walk.gif" alt="Walk Animation" style="width:100%">
#   </div>
# </div>

# %% [markdown]
# ### The Beat

# %%
from IPython.display import IFrame

IFrame('https://stonekick.com/metronome.html', width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="https://stonekick.com/metronome.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
https://www.google.com/search?q=metronome+online&sca_esv=579969189&sxsrf=AM9HkKkUj2bnvT3_Redwt7IXVtAceiQEMQ%3A1699316077505&ei=bYFJZYeqHoaki-gPl5O54Ag&ved=0ahUKEwjHlKTZzbCCAxUG0gIHHZdJDowQ4dUDCBA&uact=5&oq=metronome+online&gs_lp=...&sclient=gws-wiz-serp
# Out:
#   Cell In[39], line 1
#     https://www.google.com/search?q=metronome+online&sca_esv=579969189&sxsrf=AM9HkKkUj2bnvT3_Redwt7IXVtAceiQEMQ%3A1699316077505&ei=bYFJZYeqHoaki-gPl5O54Ag&ved=0ahUKEwjHlKTZzbCCAxUG0gIHHZdJDowQ4dUDCBA&uact=5&oq=metronome+online&gs_lp=...&sclient=gws-wiz-serp
#                                                                                                                 ^
# SyntaxError: invalid decimal literal

# %%
from IPython.display import IFrame

IFrame('https://metronome-online.com/', width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="https://metronome-online.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame

IFrame('https://guitarapp.com/metronome.html?tempo=120&timeSignature=2&pattern=1', width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="https://guitarapp.com/metronome.html?tempo=120&timeSignature=2&pattern=1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# (Theory) -> Associate it with a speed that you will use to meassure your piece and give you the time unit
# (Animation) -> A moving metronome that allows you to change the speed (students can change it and get a general idea of pulse + speed)

# %% [markdown]
# <iframe src="https://guitarapp.com/metronome.html?embed=true&tempo=120&timeSignature=2&pattern=1" title="Online Metronome" style="width: 360px; height:520px; border-style: none; border-radius: 4px;"> </iframe>

# %% [markdown]
# <iframe src="https://guitarapp.com/metronome.html?embed=true&tempo=120&timeSignature=2&pattern=1&theme=light" title="Online Metronome" style="width: 360px; height:520px; border-style: none; border-radius: 4px;"> </iframe>

# %% [markdown]
# ### The Tempo

# %% [markdown]
# <hr />

# %% [markdown]
# ## Figures

# %% [markdown]
# (Theory) -> use the time unit to explain its division in each figure (mathematically)
# (Visual) -> explain this while showing the figures -> an image with name and notation of eah figure and its subdivision
# (Animation) -> put an image of each figure and an audio that (when hitted play) reproduces the sound of that figure with smt like a light highlighting the beat (sounding at the same time)

# %% [markdown]
# #### Weight

# %% [markdown]
# (Theory) -> slightly explain that figures have weights and that helps musical flow and rythm articulation -> time signature
# (Visual) -> a pyramid of weights (semibreve on the top, then breve...)
# Connect this with the time signature

# %% [markdown]
# <hr />

# %% [markdown]
# ## Time signature

# %% [markdown]
# (Theory) -> upper number indicates number of beats, lower number indicates the time unit
# Just explain easy time signatures (to not make lecture long and bc its for begginers)
# usar induction para decir cómo se reparte el peso en el compás según lo explicado en apartado anterior
# relacionarlo con el meter

# %% [markdown]
# <hr />

# %% [markdown]
# (examples)

# %% [markdown]
# ### Love Runs Out - One Republic

# %%
from IPython.display import Image
# Photos credit: https://commons.wikimedia.org/wiki/File:Rolex_Learning_center.jpg
Image('Love Runs Out.png', width=1000,height=600)

# %%
from scipy.io import loadmat, wavfile
from IPython.lib.display import Audio

# import the speech from a wav file
r,speech = wavfile.read('LoveRunsOut.wav')
_,rir = wavfile.read('LoveRunsOut.wav')

# Add the audio widget
print('Speech')
display(Audio(data=speech, rate=r))
print('Room Impulse Response')
display(Audio(data=rir[:,0], rate=r))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/carolinaalbamaruganrubio/ApuntesCARRERA/5º/Digital Education/Instruction.ipynb Cell 34 line 5
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a> from IPython.lib.display import Audio
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#Y105sZmlsZQ%3D%3D?line=3'>4</a> # import the speech from a wav file
# ----> <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#Y105sZmlsZQ%3D%3D?line=4'>5</a> r,speech = wavfile.read('LoveRunsOut.wav')
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#Y105sZmlsZQ%3D%3D?line=5'>6</a> _,rir = wavfile.read('LoveRunsOut.wav')
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#Y105sZmlsZQ%3D%3D?line=7'>8</a> # Add the audio widget
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/io/wavfile.py:650, in read(filename, mmap)
#     647     fid = open(filename, 'rb')
#     649 try:
# --> 650     file_size, is_big_endian = _read_riff_chunk(fid)
#     651     fmt_chunk_received = False
#     652     data_chunk_received = False
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/io/wavfile.py:521, in _read_riff_chunk(fid)
#     518     fmt = '>I'
#     519 else:
#     520     # There are also .wav files with "FFIR" or "XFIR" signatures?
# --> 521     raise ValueError(f"File format {repr(str1)} not understood. Only "
#     522                      "'RIFF' and 'RIFX' supported.")
#     524 # Size of entire file
#     525 file_size = struct.unpack(fmt, fid.read(4))[0] + 8
#
# ValueError: File format b'\x1aE\xdf\xa3' not understood. Only 'RIFF' and 'RIFX' supported.

# %% [markdown]
# we show the notation of the song without notes, just figures and next to the image they can hit play to reproduce the song
# (Visual) -> figure with standard notation + (Audio) -> just audio of the song

# %% [markdown]
# ### Auf uns - Bourani

# %% [markdown]
# ### Thunder - AC/DC

# %% [markdown]
# <hr />

# %% [markdown]
# Teaching Links:
# https://notebooks.gesis.org/binder/jupyter/user/theboilingpoint-cation-fall2023-zuo00d42/doc/tree/jupyterTutorial.ipynb
# https://docs.moodle.org/402/en/Interactive_Content_-_H5P_activity
# https://www.epfl.ch/education/educational-initiatives/jupyter-notebooks-for-education/teaching-and-learning-with-jupyter-notebooks/
# https://www.epfl.ch/education/educational-initiatives/jupyter-notebooks-for-education/teaching-and-learning-with-jupyter-notebooks/online-interactive-textbooks-with-jupyter-notebooks/

# %% [markdown]
# (examples on how to get some resources)

# %% [markdown]
# ### video

# %%
from IPython.display import YouTubeVideo
from datetime import timedelta

# It is possible to start the video at a specific time
start=int(timedelta(hours=0, minutes=0, seconds=0).total_seconds())

YouTubeVideo("OJy2h9mgiX8", start=start, autoplay=0, theme="light", color="red")

# %%
from IPython.display import VimeoVideo

VimeoVideo("12891305")

# %% [markdown]
# ### website

# %%
from IPython.display import IFrame

IFrame('https://dlab.epfl.ch/teaching/fall2019/cs401/', width=800, height=600)

# %% [markdown]
# ### audio

# %%
from scipy.io import loadmat, wavfile
from IPython.lib.display import Audio

# import the speech from a wav file
r,speech = wavfile.read('Data/german_speech_44100.wav')
_,rir = wavfile.read('Data/RIRs.wav')

# Add the audio widget
print('Speech')
display(Audio(data=speech, rate=r))
print('Room Impulse Response')
display(Audio(data=rir[:,0], rate=r))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /Users/carolinaalbamaruganrubio/ApuntesCARRERA/5º/Digital Education/Instruction.ipynb Cell 49 line 8
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a> sample_rate, data = wavfile.read("LoveRunsOut.wav")
#       <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#X46sZmlsZQ%3D%3D?line=6'>7</a> # Display the audio
# ----> <a href='vscode-notebook-cell:/Users/carolinaalbamaruganrubio/ApuntesCARRERA/5%C2%BA/Digital%20Education/Instruction.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> Audio(data, rate=sample_rate)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/lib/display.py:130, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     128 if rate is None:
#     129     raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
# --> 130 self.data = Audio._make_wav(data, rate, normalize)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/lib/display.py:162, in Audio._make_wav(data, rate, normalize)
#     160 waveobj.setsampwidth(2)
#     161 waveobj.setcomptype('NONE','NONE')
# --> 162 waveobj.writeframes(scaled)
#     163 val = fp.getvalue()
#     164 waveobj.close()
#
# File ~/anaconda3/lib/python3.11/wave.py:558, in Wave_write.writeframes(self, data)
#     557 def writeframes(self, data):
# --> 558     self.writeframesraw(data)
#     559     if self._datalength != self._datawritten:
#     560         self._patchheader()
#
# File ~/anaconda3/lib/python3.11/wave.py:547, in Wave_write.writeframesraw(self, data)
#     545 if not isinstance(data, (bytes, bytearray)):
#     546     data = memoryview(data).cast('B')
# --> 547 self._ensure_header_written(len(data))
#     548 nframes = len(data) // (self._sampwidth * self._nchannels)
#     549 if self._convert:
#
# File ~/anaconda3/lib/python3.11/wave.py:588, in Wave_write._ensure_header_written(self, datasize)
#     586 if not self._framerate:
#     587     raise Error('sampling rate not specified')
# --> 588 self._write_header(datasize)
#
# File ~/anaconda3/lib/python3.11/wave.py:600, in Wave_write._write_header(self, initlength)
#     598 except (AttributeError, OSError):
#     599     self._form_length_pos = None
# --> 600 self._file.write(struct.pack('<L4s4sLHHLLHH4s',
#     601     36 + self._datalength, b'WAVE', b'fmt ', 16,
#     602     WAVE_FORMAT_PCM, self._nchannels, self._framerate,
#     603     self._nchannels * self._framerate * self._sampwidth,
#     604     self._nchannels * self._sampwidth,
#     605     self._sampwidth * 8, b'data'))
#     606 if self._form_length_pos is not None:
#     607     self._data_length_pos = self._file.tell()
#
# error: ushort format requires 0 <= number <= 65535

# %% [markdown]
# ### image

# %%
from IPython.display import Image
# Photos credit: https://commons.wikimedia.org/wiki/File:Rolex_Learning_center.jpg
Image('./Data/rlc.jpg', width=800,height=600)
